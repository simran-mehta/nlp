# %% [markdown]
# <h2 align='center'>NLP Tutorial: Text Representation - Bag Of Words (BOW)</h2>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x =='spam' else 0)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %% [markdown]
# <h3>Train test split</h3>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 5403             So gd got free ice cream... I oso wan...
# 1766    Hi this is yijue... It's regarding the 3230 te...
# 724              Ya even those cookies have jelly on them
# 3966                         Love you aathi..love u lot..
# Name: Message, dtype: object

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 5403    0
# 1766    0
# 724     0
# 3966    0
# Name: spam, dtype: int64

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %% [markdown]
# <h3>Create bag of words representation using CountVectorizer</h3>

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <4457x7695 sparse matrix of type '<class 'numpy.int64'>'
# 	with 58931 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train_cv.shape
# Out:
# (4457, 7695)

# %%
v.get_feature_names_out()[1771]
# Out:
# 'chik'

# %%
v.vocabulary_
# Out:
# {'so': 6234,
#  'gd': 3084,
#  'got': 3190,
#  'free': 2973,
#  'ice': 3568,
#  'cream': 2053,
#  'oso': 4968,
#  'wan': 7322,
#  'hi': 3411,
#  'this': 6806,
#  'is': 3725,
#  'yijue': 7647,
#  'it': 3736,
#  'regarding': 5628,
#  'the': 6766,
#  '3230': 443,
#  'textbook': 6742,
#  'intro': 3697,
#  'to': 6886,
#  'algorithms': 907,
#  'second': 5928,
#  'edition': 2509,
#  'selling': 5959,
#  'for': 2926,
#  '50': 535,
#  'ya': 7615,
#  'even': 2642,
#  'those': 6814,
#  'cookies': 1991,
#  'have': 3342,
#  'jelly': 3788,
#  'on': 4901,
#  'them': 6775,
#  'love': 4199,
#  'you': 7654,
#  'aathi': 745,
#  'lot': 4186,
#  'yup': 7681,
#  'no': 4757,
#  'need': 4688,
#  'll': 4133,
#  'jus': 3848,
#  'wait': 7302,
#  'rain': 5510,
#  'stop': 6444,
#  'ugh': 7065,
#  'fuck': 3019,
#  'resubbing': 5711,
#  'eve': 2640,
#  'we': 7362,
#  'can': 1625,
#  'go': 3149,
#  'normal': 4783,
#  'pilates': 5179,
#  'after': 852,
#  'our': 4977,
#  'let': 4058,
#  'me': 4377,
#  'know': 3931,
#  'if': 3586,
#  'anything': 999,
#  'else': 2544,
#  'salad': 5835,
#  'or': 4943,
#  'desert': 2245,
#  'something': 6255,
#  'how': 3505,
#  'many': 4321,
#  'beers': 1293,
#  'shall': 6013,
#  'get': 3108,
#  're': 5550,
#  'met': 4430,
#  'alex': 903,
#  'nichols': 4731,
#  'from': 3011,
#  'middle': 4438,
#  'school': 5895,
#  'and': 957,
#  'turns': 7031,
#  'out': 4980,
#  'he': 3352,
#  'dealing': 2172,
#  'today': 6892,
#  'am': 932,
#  'going': 3161,
#  'college': 1885,
#  'not': 4790,
#  'able': 755,
#  'atten': 1124,
#  'class': 1819,
#  'please': 5216,
#  'reserve': 5690,
#  'ticket': 6843,
#  'saturday': 5875,
#  'chennai': 1757,
#  'thirunelvali': 6805,
#  'again': 859,
#  'tirunelvali': 6863,
#  'sunday': 6551,
#  'already': 922,
#  'see': 5941,
#  'in': 3625,
#  'net': 4705,
#  'available': 1150,
#  'want': 7326,
#  'book': 1425,
#  'through': 6827,
#  'tackle': 6632,
#  'job': 3808,
#  'wipro': 7482,
#  'will': 7465,
#  'every': 2649,
#  'thing': 6795,
#  'life': 4072,
#  'years': 7631,
#  'lt': 4220,
#  'gt': 3246,
#  'ish': 3728,
#  'minutes': 4466,
#  'was': 7338,
#  'ago': 869,
#  'wtf': 7582,
#  'ard': 1044,
#  '530': 550,
#  'like': 4082,
#  'dat': 2152,
#  'lor': 4179,
#  'juz': 3854,
#  'meet': 4394,
#  'mrt': 4578,
#  'station': 6404,
#  'then': 6779,
#  'dun': 2468,
#  'haf': 3279,
#  'come': 1894,
#  'think': 6797,
#  'just': 3849,
#  'yourself': 7665,
#  'thanks': 6756,
#  'tomo': 6910,
#  'there': 6784,
#  'os': 4967,
#  'called': 1609,
#  'ubandu': 7062,
#  'which': 7436,
#  'run': 5810,
#  'without': 7498,
#  'installing': 3677,
#  'hard': 3321,
#  'disk': 2329,
#  'use': 7171,
#  'that': 6762,
#  'copy': 2000,
#  'important': 3615,
#  'files': 2829,
#  'system': 6624,
#  'give': 3135,
#  'repair': 5667,
#  'shop': 6065,
#  'fast': 2767,
#  'approaching': 1029,
#  'wish': 7486,
#  'very': 7222,
#  'happy': 3320,
#  'new': 4719,
#  'year': 7630,
#  'sankranti': 5854,
#  'republic': 5680,
#  'day': 2161,
#  'valentines': 7191,
#  'shivratri': 6057,
#  'ugadi': 7064,
#  'fools': 2920,
#  'may': 4368,
#  'independence': 3644,
#  'friendship': 2998,
#  'mother': 4558,
#  'father': 2772,
#  'teachers': 6684,
#  'childrens': 1777,
#  'amp': 948,
#  'birthday': 1364,
#  'ganesh': 3062,
#  'festival': 2804,
#  'dasara': 2151,
#  'diwali': 2343,
#  'christmas': 1801,
#  'good': 3173,
#  'mornings': 4552,
#  'afternoons': 855,
#  'evenings': 2644,
#  'nights': 4741,
#  'rememberi': 5647,
#  'first': 2860,
#  'wishing': 7490,
#  'all': 911,
#  'these': 6786,
#  'your': 7660,
#  'raj': 5514,
#  'missing': 4478,
#  'too': 6925,
#  'pray': 5334,
#  'inshah': 3673,
#  'allah': 912,
#  'call': 1602,
#  'later': 4002,
#  'pls': 5224,
#  'yes': 7640,
#  'crickiting': 2065,
#  'mind': 4453,
#  'huh': 3529,
#  'cant': 1636,
#  'thk': 6807,
#  'of': 4857,
#  'more': 4547,
#  'oredi': 4954,
#  'pages': 5018,
#  'do': 2351,
#  'dear': 2174,
#  'friends': 2996,
#  'sorry': 6280,
#  'late': 3999,
#  'information': 3656,
#  'loving': 4209,
#  'ar': 1039,
#  'praveesh': 5333,
#  'details': 2254,
#  'log': 4149,
#  'face': 2729,
#  'its': 3743,
#  'his': 3426,
#  'number': 4818,
#  'dont': 2387,
#  'miss': 4475,
#  'delicious': 2216,
#  'treat': 6982,
#  '400': 476,
#  'xmas': 7601,
#  'reward': 5729,
#  'waiting': 7305,
#  'computer': 1929,
#  'has': 3330,
#  'randomly': 5528,
#  'picked': 5166,
#  'loyal': 4215,
#  'mobile': 4507,
#  'customers': 2111,
#  'receive': 5587,
#  '09066380611': 233,
#  'did': 2277,
#  'film': 2834,
#  'why': 7450,
#  'tired': 6860,
#  'what': 7420,
#  'special': 6311,
#  'had': 3278,
#  'oh': 4876,
#  'bought': 1447,
#  'eggs': 2524,
#  'wat': 7345,
#  'doing': 2373,
#  'now': 4802,
#  'lol': 4158,
#  'great': 3224,
#  'im': 3600,
#  'getting': 3116,
#  'hungry': 3536,
#  'princess': 5380,
#  'catch': 1679,
#  'with': 7494,
#  'my': 4628,
#  'big': 1344,
#  'strong': 6479,
#  'hands': 3299,
#  'alright': 923,
#  'head': 3353,
#  'few': 2808,
#  'text': 6740,
#  'where': 7430,
#  'heard': 3365,
#  'u4': 7060,
#  'while': 7437,
#  'rude': 5799,
#  'chat': 1734,
#  'private': 5389,
#  'line': 4095,
#  '01223585334': 4,
#  'cum': 2096,
#  '2c': 388,
#  'pics': 5169,
#  'gettin': 3115,
#  'shagged': 6006,
#  'pix': 5190,
#  '8552': 678,
#  '2end': 391,
#  'send': 5964,
#  'sam': 5844,
#  'xxx': 7606,
#  'schedule': 5894,
#  'next': 4726,
#  'week': 7384,
#  'town': 6956,
#  'weekend': 7386,
#  'dnt': 2350,
#  'worry': 7550,
#  'pieces': 5175,
#  'cloth': 1842,
#  'pack': 5013,
#  'also': 925,
#  'take': 6641,
#  'tablets': 6631,
#  'pple': 5315,
#  'marry': 4335,
#  'their': 6772,
#  'lovers': 4206,
#  'becz': 1282,
#  'they': 6790,
#  'hav': 3339,
#  'gud': 3251,
#  'undrstndng': 7099,
#  'avoids': 1161,
#  'problems': 5399,
#  'sent': 5973,
#  'dis': 2314,
#  'wil': 7462,
#  'news': 4724,
#  'friday': 2991,
#  'by': 1586,
#  'person': 5130,
#  'tomorrow': 6912,
#  'be': 1268,
#  'best': 1324,
#  'break': 1490,
#  'chain': 1710,
#  'suffer': 6531,
#  'frnds': 3005,
#  'mins': 4463,
#  'whn': 7441,
#  'read': 5557,
#  'ok': 4881,
#  'night': 4738,
#  'warm': 7332,
#  'bath': 1243,
#  'drink': 2430,
#  'cup': 2099,
#  'milk': 4447,
#  'work': 7538,
#  'magic': 4281,
#  'still': 6433,
#  'loose': 4176,
#  'weight': 7391,
#  'hey': 3407,
#  'babe': 1185,
#  'doin': 2371,
#  'wot': 7556,
#  'up': 7136,
#  '2nite': 412,
#  'annie': 970,
#  'are': 1045,
#  'probably': 5397,
#  'having': 3348,
#  'much': 4598,
#  'fun': 3032,
#  'message': 4424,
#  'but': 1574,
#  'thought': 6818,
#  'id': 3573,
#  'txt': 7044,
#  'cos': 2008,
#  'bored': 1435,
#  'james': 3765,
#  'been': 1289,
#  'farting': 2765,
#  'at': 1112,
#  'scotland': 5904,
#  'hope': 3473,
#  'over': 4994,
#  'showing': 6089,
#  'jjc': 3806,
#  'tendencies': 6718,
#  'care': 1650,
#  'live': 4125,
#  'dream': 2424,
#  'records': 5604,
#  'indicate': 3649,
#  'maybe': 4370,
#  'entitled': 2594,
#  '5000': 537,
#  'pounds': 5308,
#  'compensation': 1914,
#  'accident': 778,
#  'claim': 1811,
#  'reply': 5674,
#  'msg': 4580,
#  'home': 3458,
#  'always': 930,
#  'means': 4383,
#  'because': 1278,
#  'people': 5112,
#  'world': 7545,
#  'calls': 1616,
#  'ge': 3086,
#  'any': 991,
#  'movies': 4570,
#  'laptop': 3988,
#  'fighting': 2823,
#  'easy': 2494,
#  'either': 2532,
#  'win': 7468,
#  'lose': 4181,
#  'bt': 1539,
#  'fightng': 2824,
#  'some1': 6247,
#  'who': 7442,
#  'close': 1838,
#  'dificult': 2292,
#  'interview': 3692,
#  'joy': 3830,
#  'john': 3814,
#  'name': 4647,
#  'mandan': 4313,
#  'alone': 919,
#  '2p': 414,
#  'per': 5114,
#  'min': 4451,
#  'germany': 3107,
#  '08448350055': 62,
#  'check': 1744,
#  'planettalkinstant': 5201,
#  'com': 1889,
#  'info': 3654,
#  'opt': 4937,
#  'darlin': 2145,
#  'finish': 2847,
#  'pick': 5165,
#  'back': 1194,
#  'luv': 4236,
#  'kate': 3871,
#  '88066': 695,
#  'lost': 4185,
#  '3pound': 468,
#  'help': 3387,
#  'fills': 2833,
#  'complete': 1921,
#  'calm': 1618,
#  'reassurance': 5577,
#  'when': 7426,
#  'ur': 7154,
#  'visa': 7253,
#  'coming': 1899,
#  'buying': 1579,
#  'gucci': 3250,
#  'bags': 1201,
#  'sister': 6142,
#  'things': 6796,
#  'uncle': 7083,
#  'own': 5005,
#  'bills': 1352,
#  'really': 5570,
#  'about': 757,
#  'make': 4297,
#  'money': 4532,
#  'sha': 6003,
#  'some': 6246,
#  'time': 6853,
#  'walk': 7310,
#  'ringtone': 5749,
#  'order': 4951,
#  'reference': 5613,
#  'x29': 7594,
#  'charged': 1727,
#  'should': 6078,
#  'tone': 6914,
#  'arrive': 1074,
#  'customer': 2109,
#  'services': 5984,
#  '09065989180': 221,
#  'hahaha': 3281,
#  'brain': 1476,
#  'meeting': 4396,
#  'tmr': 6881,
#  'hmm': 3438,
#  'bring': 1509,
#  'bottle': 1445,
#  'wine': 7474,
#  'keep': 3879,
#  'us': 7167,
#  'amused': 951,
#  'joking': 3822,
#  'red': 5609,
#  'white': 7440,
#  '1st': 336,
#  'entry': 2596,
#  'textpod': 6749,
#  'chance': 1715,
#  '40gb': 480,
#  'ipod': 3713,
#  '250': 373,
#  'cash': 1672,
#  'wk': 7503,
#  'pod': 5252,
#  '84128': 670,
#  'ts': 7010,
#  'cs': 2079,
#  'www': 7591,
#  'custcare': 2108,
#  '08712405020': 110,
#  'here': 3400,
#  'sale': 5838,
#  'baby': 1188,
#  'nasty': 4660,
#  'filthyguys': 2838,
#  'fancy': 2758,
#  'sexy': 5997,
#  'bitch': 1367,
#  'slo': 6183,
#  '4msgs': 520,
#  'thank': 6755,
#  'congratulations': 1955,
#  'awarded': 1166,
#  'yrs': 7672,
#  'supply': 6567,
#  'cds': 1692,
#  'virgin': 7250,
#  'mystery': 4635,
#  'gift': 3123,
#  'guaranteed': 3249,
#  '09061104283': 188,
#  'smsco': 6214,
#  '50pm': 544,
#  'approx': 1033,
#  '3mins': 465,
#  'finally': 2841,
#  'came': 1621,
#  'fix': 2867,
#  'ceiling': 1694,
#  'right': 5741,
#  'nah': 4642,
#  'perpetual': 5127,
#  'dd': 2167,
#  'thanx': 6760,
#  'dump': 2467,
#  'heap': 3363,
#  'mom': 4525,
#  'decided': 2183,
#  'lowes': 4213,
#  'boring': 1437,
#  'understand': 7094,
#  'loss': 4184,
#  'gain': 3051,
#  'luck': 4224,
#  'draw': 2421,
#  'takes': 6644,
#  'place': 5194,
#  '28th': 384,
#  'feb': 2787,
#  '06': 17,
#  'removal': 5656,
#  '87239': 691,
#  '08708034412': 90,
#  'till': 6852,
#  'end': 2564,
#  'march': 4324,
#  'el': 2533,
#  'nino': 4747,
#  'gets': 3112,
#  'himself': 3421,
#  'wkly': 7507,
#  'comp': 1908,
#  'fa': 2726,
#  'final': 2839,
#  'tkts': 6874,
#  '21st': 361,
#  '2005': 352,
#  '87121': 688,
#  'question': 5487,
#  'std': 6411,
#  'rate': 5534,
#  'apply': 1021,
#  '08452810075over18': 67,
#  'battery': 1248,
#  'died': 2282,
#  'yeah': 7629,
#  'whats': 7422,
#  'house': 3500,
#  'beer': 1291,
#  'sunshine': 6557,
#  'quiz': 5496,
#  'top': 6934,
#  'sony': 6267,
#  'dvd': 2476,
#  'player': 5209,
#  'country': 2025,
#  'algarve': 905,
#  'ansr': 981,
#  '82277': 652,
#  'sp': 6301,
#  'tyrone': 7059,
#  'wnt': 7515,
#  'buy': 1578,
#  'bmw': 1410,
#  'car': 1645,
#  'urgently': 7159,
#  'vry': 7279,
#  'urgent': 7158,
#  'hv': 3549,
#  'shortage': 6071,
#  'lacs': 3962,
#  'source': 6295,
#  'arng': 1065,
#  'amt': 950,
#  'thats': 6765,
#  'prob': 5396,
#  'hols': 3456,
#  'med': 4389,
#  'holiday': 3453,
#  'stamped': 6384,
#  'self': 5955,
#  'address': 815,
#  'envelope': 2600,
#  'drinks': 2433,
#  'uk': 7071,
#  'po': 5234,
#  'box': 1453,
#  '113': 273,
#  'bray': 1485,
#  'wicklow': 7453,
#  'eire': 2531,
#  'starts': 6398,
#  'unsub': 7130,
#  'last': 3996,
#  '150': 305,
#  'worth': 7554,
#  'discount': 2325,
#  'vouchers': 7277,
#  '85023': 674,
#  'savamob': 5878,
#  'offers': 4866,
#  'pobox84': 5246,
#  'm263uz': 4252,
#  '00': 0,
#  'sub': 6504,
#  '16': 318,
#  'watch': 7346,
#  'say': 5884,
#  'cause': 1683,
#  'drunk': 2448,
#  'as': 1083,
#  'motherfucker': 4559,
#  'excellent': 2678,
#  'spent': 6326,
#  'air': 882,
#  'force': 2927,
#  'iraq': 3715,
#  'afghanistan': 847,
#  'stable': 6376,
#  'honest': 3461,
#  'traveling': 6976,
#  'song': 6265,
#  'bro': 1517,
#  'creative': 2055,
#  'neva': 4714,
#  'test': 6734,
#  'quality': 5481,
#  'said': 5833,
#  'review': 5727,
#  'online': 4910,
#  'rite': 5758,
#  'well': 7399,
#  'mate': 4350,
#  'pete': 5139,
#  'went': 7405,
#  'were': 7407,
#  '2geva': 396,
#  'longer': 4166,
#  'than': 6752,
#  'down': 2407,
#  'gandhipuram': 3061,
#  'cross': 2069,
#  'cut': 2113,
#  'road': 5760,
#  'side': 6105,
#  'street': 6465,
#  'turn': 7029,
#  'usual': 7181,
#  'iam': 3557,
#  'fine': 2845,
#  'aww': 1170,
#  'must': 4622,
#  'nearly': 4681,
#  'dead': 2169,
#  'jez': 3800,
#  'iscoming': 3727,
#  'todo': 6894,
#  'workand': 7540,
#  'whilltake': 7438,
#  'forever': 2931,
#  'ideas': 3577,
#  'don': 2383,
#  'though': 6817,
#  'put': 5472,
#  'poorly': 5275,
#  'punishment': 5458,
#  'worst': 7553,
#  'ever': 2648,
#  'happened': 3312,
#  'brb': 1486,
#  'gonna': 3172,
#  'kill': 3906,
#  'myself': 4633,
#  'real': 5562,
#  'she': 6028,
#  'told': 6902,
#  'dad': 2127,
#  'cancer': 1631,
#  't91': 6627,
#  'gbp': 3082,
#  'unsubscribe': 7131,
#  'anytime': 1001,
#  'calling': 1615,
#  '09057039994': 172,
#  'mm': 4494,
#  'feeling': 2794,
#  'sleepy': 6175,
#  'itself': 3744,
#  'rats': 5538,
#  'vote': 7273,
#  'themes': 6777,
#  'vijay': 7237,
#  'different': 2289,
#  'jamster': 3766,
#  'crazy': 2052,
#  'frog': 3010,
#  'sound': 6290,
#  'poly': 5262,
#  'mad1': 4270,
#  'mad2': 4271,
#  '88888': 702,
#  'sounds': 6292,
#  'only': 4912,
#  '200': 348,
#  'shopping': 6067,
#  'spree': 6362,
#  '08717895698': 136,
#  'won': 7522,
#  'mobstorequiz10ppm': 4513,
#  'cool': 1993,
#  'liked': 4083,
#  'photos': 5159,
#  'email': 2548,
#  'alertfrom': 900,
#  'jeri': 3792,
#  'stewartsize': 6427,
#  '2kbsubject': 401,
#  'low': 4211,
#  'cost': 2010,
#  'prescripiton': 5354,
#  'drvgsto': 2451,
#  'listen': 4114,
#  '123': 284,
#  'unni': 7124,
#  'recharge': 5595,
#  'rakhesh': 5520,
#  'haha': 3280,
#  'better': 1329,
#  'way': 7358,
#  'could': 2020,
#  'swing': 6611,
#  'ring': 5746,
#  'asap': 1085,
#  'lmao': 4136,
#  'pic': 5164,
#  'spoke': 6347,
#  'mag': 4277,
#  'deliver': 2217,
#  'month': 4541,
#  '24th': 371,
#  'sept': 5977,
#  'talk': 6649,
#  'wants': 7330,
#  'little': 4124,
#  'times': 6854,
#  'ahead': 872,
#  'might': 4441,
#  'dip': 2306,
#  'cell': 1700,
#  'him': 3420,
#  'respond': 5700,
#  'attracts': 1131,
#  'brothas': 1525,
#  'arngd': 1066,
#  'marriage': 4333,
#  'walkin': 7313,
#  'unfortuntly': 7103,
#  'snake': 6220,
#  'bites': 1369,
#  'dancing': 2136,
#  'frnt': 3009,
#  'sayin': 5885,
#  'bite': 1368,
#  'party': 5065,
#  'usf': 7177,
#  'charge': 1726,
#  'contribute': 1980,
#  'greatly': 3226,
#  'appreciated': 1027,
#  'room': 5773,
#  'one': 4906,
#  'neither': 4701,
#  'sterm': 6425,
#  'voice': 7266,
#  'studying': 6493,
#  'sure': 6573,
#  'resolved': 5696,
#  'tho': 6813,
#  'anyway': 1002,
#  'fab': 2727,
#  'isn': 3731,
#  'frnd': 3004,
#  'necesity': 4682,
#  'imagine': 3604,
#  'urself': 7166,
#  'witout': 7500,
#  'hw': 3552,
#  'feel': 2792,
#  'colleg': 1884,
#  'wth': 7583,
#  'abt': 764,
#  'functions': 3034,
#  'thnk': 6810,
#  'events': 2646,
#  'espe': 2624,
#  'cared': 1652,
#  'missed': 4476,
#  'irritated': 3720,
#  '4wrd': 533,
#  'wthout': 7584,
#  'whom': 7445,
#  'jst': 3833,
#  'takecare': 6642,
#  'goodmorning': 3177,
#  'squeeeeeze': 6369,
#  'hug': 3524,
#  'lik': 4081,
#  'frndshp': 3007,
#  'den': 2225,
#  'cute': 2114,
#  'luvd': 4237,
#  'lucky': 4225,
#  'none': 4771,
#  'hate': 3335,
#  'fri': 2990,
#  'find': 2843,
#  'tom': 6906,
#  'mentionned': 4416,
#  'chinese': 1784,
#  'same': 5848,
#  'boat': 1411,
#  'moms': 4528,
#  'yo': 7649,
#  'half': 3288,
#  'naked': 4644,
#  'being': 1305,
#  'welp': 7401,
#  'apparently': 1016,
#  'retired': 5718,
#  'yesterday': 7642,
#  'cbe': 1687,
#  'lunch': 4231,
#  'chosen': 1798,
#  '350': 447,
#  'award': 1165,
#  '09066364311': 229,
#  'collect': 1880,
#  'selected': 5953,
#  'valued': 7196,
#  'under': 7092,
#  'sea': 5922,
#  'lays': 4019,
#  'rock': 5763,
#  'an': 953,
#  'paper': 5039,
#  'words': 7537,
#  'leave': 4035,
#  'couple': 2028,
#  'mu': 4596,
#  've': 7210,
#  'salt': 5843,
#  'rub': 5797,
#  'open': 4923,
#  'wounds': 7563,
#  'inside': 3674,
#  'da': 2124,
#  'park': 5054,
#  'turning': 7030,
#  'off': 4859,
#  'phone': 5153,
#  'telling': 6706,
#  'everyone': 2654,
#  'hurts': 3544,
#  'asked': 1093,
#  'anthony': 989,
#  'bf': 1335,
#  'didnt': 2280,
#  'gist': 3133,
#  'tat': 6665,
#  'tot': 6946,
#  'group': 3238,
#  'mah': 4284,
#  'askin': 1094,
#  'leaving': 4037,
#  'earlier': 2483,
#  'mayb': 4369,
#  'far': 2762,
#  '2003': 350,
#  'account': 784,
#  'statement': 6402,
#  '078': 33,
#  'howz': 3512,
#  'persons': 5135,
#  'story': 6457,
#  'cthen': 2085,
#  'shd': 6027,
#  'enuff': 2599,
#  'conclusion': 1940,
#  'contents': 1975,
#  'pg': 5143,
#  'references': 5614,
#  'cover': 2035,
#  'checking': 1747,
#  'rewarding': 5730,
#  'snow': 6230,
#  'start': 6395,
#  'around': 1068,
#  'pm': 5232,
#  'tonite': 6922,
#  'predicting': 5341,
#  'inch': 3628,
#  'accumulation': 787,
#  'family': 2754,
#  'happiness': 3319,
#  'height': 3378,
#  'shit': 6051,
#  'situation': 6149,
#  'guy': 3268,
#  'throws': 6831,
#  'letter': 4060,
#  'gal': 3053,
#  'falls': 2750,
#  'her': 3399,
#  'brothers': 1527,
#  'whos': 7447,
#  'gay': 3077,
#  'watching': 7349,
#  'tv': 7033,
#  'sleep': 6170,
#  'rhythm': 5735,
#  'establish': 2629,
#  'body': 1414,
#  'learn': 4031,
#  'touch': 6950,
#  'folks': 2905,
#  'company': 1911,
#  'age': 861,
#  'enjoy': 2580,
#  'community': 1906,
#  '150p': 307,
#  'sms': 6213,
#  'try': 7007,
#  'fact': 2731,
#  'tee': 6696,
#  'hee': 3376,
#  'stand': 6386,
#  'away': 1167,
#  'doesn': 2363,
#  'heart': 3368,
#  'ache': 789,
#  'wonder': 7525,
#  'crave': 2050,
#  'university': 7115,
#  'southern': 6298,
#  'california': 1601,
#  'boy': 1468,
#  'power': 5312,
#  'frndship': 3006,
#  'mostly': 4557,
#  'opposite': 4935,
#  'dropped': 2441,
#  'putting': 5475,
#  'fires': 2858,
#  'actually': 806,
#  'wife': 7457,
#  'knew': 3928,
#  'murder': 4614,
#  'exactly': 2675,
#  'compliments': 1927,
#  'didn': 2279,
#  'hep': 3398,
#  'immunisation': 3610,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([2053, 2973, 3084, 3190, 3568, 4968, 6234, 7322], dtype=int64),)

# %%
X_train[:4][1579]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\nlp_codebasics\codebasics\nlp\nlp_environment\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\nlp_codebasics\codebasics\nlp\nlp_environment\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\nlp_codebasics\codebasics\nlp\nlp_environment\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1579
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 X_train[:4][1579]
#
# File c:\nlp_codebasics\codebasics\nlp\nlp_environment\lib\site-packages\pandas\core\series.py:1012, in Series.__getitem__(self, key)
#    1009     return self._values[key]
#    1011 elif key_is_scalar:
# -> 1012     return self._get_value(key)
#    1014 if is_hashable(key):
#    1015     # Otherwise index.get_value will raise InvalidIndexError
#    1016     try:
#    1017         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\nlp_codebasics\codebasics\nlp\nlp_environment\lib\site-packages\pandas\core\series.py:1121, in Series._get_value(self, label, takeable)
#    1118     return self._values[label]
#    1120 # Similar to Index.get_value, but we do not fall back to positional
# -> 1121 loc = self.index.get_loc(label)
#    1123 if is_integer(loc):
#    1124     return self._values[loc]
#
# File c:\nlp_codebasics\codebasics\nlp\nlp_environment\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 1579

# %%
X_train_np[0][1771]
# Out:
# 0

# %% [markdown]
# <h3>Train the naive bayes model</h3>

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %% [markdown]
# <h3>Evaluate Performance</h3>

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       967
#            1       0.95      0.91      0.93       148
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.95      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# <h3>Train the model using sklearn pipeline and reduce number of lines of code</h3>

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       967
#            1       0.95      0.91      0.93       148
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.95      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
